# %% [markdown]
# # Hotel demo dataset

# %%
import statsmodels.formula.api as smf

import numpy as np

import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression

from sklearn.ensemble import ExtraTreesClassifier

from sklearn.preprocessing import MinMaxScaler

# %%
hotel = pd.read_csv('/Users/xue/Desktop/Farrago/Datasets/hotel_dataset/H1.csv', skipinitialspace=True)

# %%
hotel.shape
# Out:
# (40060, 31)

# %%
hotel.describe()
# Out:
#          IsCanceled      LeadTime  ArrivalDateYear  ArrivalDateWeekNumber  \
# count  40060.000000  40060.000000     40060.000000           40060.000000
# mean       0.277634     92.675686      2016.121443              27.140864
# std        0.447837     97.285315         0.722347              14.005441
# min        0.000000      0.000000      2015.000000               1.000000
# 25%        0.000000     10.000000      2016.000000              16.000000
# 50%        0.000000     57.000000      2016.000000              28.000000
# 75%        1.000000    155.000000      2017.000000              38.000000
# max        1.000000    737.000000      2017.000000              53.000000
#
#        ArrivalDateDayOfMonth  StaysInWeekendNights  StaysInWeekNights  \
# count           40060.000000          40060.000000       40060.000000
# mean               15.821243              1.189815           3.128732
# std                 8.883708              1.147812           2.461329
# ...

# %%
hotel.head()
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0       342             2015             July
# 1           0       737             2015             July
# 2           0         7             2015             July
# 3           0        13             2015             July
# 4           0        14             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  ...      DepositType  Agent Company  \
# 0                  0       2         0  ...  No Deposit         NaN     NaN
# ...

# %%
hotel.isnull().sum()
# Out:
# IsCanceled                         0
# LeadTime                           0
# ArrivalDateYear                    0
# ArrivalDateMonth                   0
# ArrivalDateWeekNumber              0
# ArrivalDateDayOfMonth              0
# StaysInWeekendNights               0
# StaysInWeekNights                  0
# Adults                             0
# Children                           0
# Babies                             0
# Meal                               0
# Country                          464
# MarketSegment                      0
# DistributionChannel                0
# IsRepeatedGuest                    0
# PreviousCancellations              0
# PreviousBookingsNotCanceled        0
# ReservedRoomType                   0
# AssignedRoomType                   0
# BookingChanges                     0
# DepositType                        0
# Agent                           8209
# Company                        36952
# DaysInWaitingList                  0
# ...

# %%
canceled = hotel.loc[hotel['IsCanceled']==1][:2500]
not_canceled = hotel.loc[hotel['IsCanceled']==0][:2500]

# %%
hotel_new = pd.concat([canceled, not_canceled], ignore_index=True)

# %%
hotel_new = np.take(hotel_new,np.random.permutation(hotel_new.shape[0]),axis=0).reset_index(drop=True)

# %%
hotel_new.columns
# Out:
# Index(['IsCanceled', 'LeadTime', 'ArrivalDateYear', 'ArrivalDateMonth',
#        'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth',
#        'StaysInWeekendNights', 'StaysInWeekNights', 'Adults', 'Children',
#        'Babies', 'Meal', 'Country', 'MarketSegment', 'DistributionChannel',
#        'IsRepeatedGuest', 'PreviousCancellations',
#        'PreviousBookingsNotCanceled', 'ReservedRoomType', 'AssignedRoomType',
#        'BookingChanges', 'DepositType', 'Agent', 'Company',
#        'DaysInWaitingList', 'CustomerType', 'ADR', 'RequiredCarParkingSpaces',
#        'TotalOfSpecialRequests', 'ReservationStatusDate'],
#       dtype='object')

# %%
hotel_new.drop('ReservationStatus', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-123-c23867ad36be> in <module>
# ----> 1 hotel_new.drop('ReservationStatus', axis=1, inplace=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
hotel_new.shape
# Out:
# (5000, 30)

# %%
hotel_new.corr()
# Out:
#                              IsCanceled  LeadTime  ArrivalDateYear  \
# IsCanceled                     1.000000  0.166385         0.432791
# LeadTime                       0.166385  1.000000         0.189933
# ArrivalDateYear                0.432791  0.189933         1.000000
# ArrivalDateWeekNumber         -0.339061 -0.116253        -0.871360
# ArrivalDateDayOfMonth         -0.002745  0.000091        -0.017004
# StaysInWeekendNights           0.022382  0.228821        -0.030081
# StaysInWeekNights             -0.008173  0.271995        -0.026036
# Adults                         0.040008  0.216430        -0.027341
# Children                       0.012467 -0.077908        -0.029121
# Babies                        -0.035949 -0.012446        -0.055212
# IsRepeatedGuest                     NaN       NaN              NaN
# PreviousCancellations               NaN       NaN              NaN
# PreviousBookingsNotCanceled         NaN       NaN              NaN
# ...

# %%
dtypes = {

        'IsCanceled':                                    'float64',

        'LeadTime':                                          'float64',

        'StaysInWeekendNights':                                     'float64',

        'StaysInWeekNights':                                     'float64',

        'Adults':                            'float64',

        'Children':                            'float64',

        'Babies':                                  'float64',

        'Meal':                                    'category',

        'Country':                                               'category',

        'MarketSegment':                                    'category',

        'DistributionChannel':                                       'category',

        'IsRepeatedGuest':                               'float64',

        'PreviousCancellations':                                    'float64',

        'PreviousBookingsNotCanceled':                          'float64',

        'ReservedRoomType':                                             'category',

        'AssignedRoomType':                                            'category',

        'BookingChanges':                                                'float64',

        'DepositType':                                              'category',

        'Agent':                                              'category',

        'Company':                                 'category',

        'DaysInWaitingList':                                           'float64',

        'CustomerType':                                           'category',

        'ADR':                                          'float64',

        'RequiredCarParkingSpaces':                                      'float64',

        'TotalOfSpecialRequests':                                              'float64',

        'ReservationStatus':                                                'category'

        }

# %%
dtypes
# Out:
# {'IsCanceled': 'float64',
#  'LeadTime': 'float64',
#  'StaysInWeekendNights': 'float64',
#  'StaysInWeekNights': 'float64',
#  'Adults': 'float64',
#  'Children': 'float64',
#  'Babies': 'float64',
#  'Meal': 'category',
#  'Country': 'category',
#  'MarketSegment': 'category',
#  'DistributionChannel': 'category',
#  'IsRepeatedGuest': 'float64',
#  'PreviousCancellations': 'float64',
#  'PreviousBookingsNotCanceled': 'float64',
#  'ReservedRoomType': 'category',
#  'AssignedRoomType': 'category',
#  'BookingChanges': 'float64',
#  'DepositType': 'category',
#  'Agent': 'category',
#  'Company': 'category',
#  'DaysInWaitingList': 'float64',
#  'CustomerType': 'category',
#  'ADR': 'float64',
#  'RequiredCarParkingSpaces': 'float64',
#  'TotalOfSpecialRequests': 'float64',
#  'ReservationStatus': 'category'}

# %%
feature = []
for key in dtypes:
    feature.append(key)
print(feature)
# Out:
# ['IsCanceled', 'LeadTime', 'StaysInWeekendNights', 'StaysInWeekNights', 'Adults', 'Children', 'Babies', 'Meal', 'Country', 'MarketSegment', 'DistributionChannel', 'IsRepeatedGuest', 'PreviousCancellations', 'PreviousBookingsNotCanceled', 'ReservedRoomType', 'AssignedRoomType', 'BookingChanges', 'DepositType', 'Agent', 'Company', 'DaysInWaitingList', 'CustomerType', 'ADR', 'RequiredCarParkingSpaces', 'TotalOfSpecialRequests', 'ReservationStatus']

# %%
print(set(hotel_new)-set(feature))
# Out:
# {'ArrivalDateWeekNumber', 'ReservationStatusDate', 'ArrivalDateMonth', 'ArrivalDateYear', 'ArrivalDateDayOfMonth'}

# %%
hotel_new.drop(['ArrivalDateWeekNumber', 'ReservationStatusDate', 
                'ArrivalDateMonth', 'ArrivalDateYear', 'ArrivalDateDayOfMonth'], axis=1, inplace=True)

# %%
hotel_new.shape
# Out:
# (5000, 25)

# %%
hotel_new.drop(['Babies', 'DaysInWaitingList', 'Company',
                'PreviousBookingsNotCanceled', 'Meal', 'Adults',
               'StaysInWeekNights'], axis=1, inplace=True)

# %%
hotel_new.shape
# Out:
# (5000, 18)

# %%
hotel_new.to_csv('Hotel_Cancellations.csv', index= False)
